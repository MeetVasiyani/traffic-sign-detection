# %%
from PIL import Image
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# It imports the Image module from the PIL (Python Imaging Library) package so you can work with images in Python.
#
# Opening image files
#
# Editing images
#
# Resizing
#
# Cropping
#
# Rotating
#
# Converting image formats
#
# Saving images

# %%
# !cp -r /content/drive/MyDrive/DeepLearningProject/data/train/task2train540p /content/
# Out:
# cp: cannot stat '/content/drive/MyDrive/DeepLearningProject/data/train/task2train540p': No such file or directory

# %%
import os

train_path = "/content/task2train540p"

classes = os.listdir(train_path)

print("Classes Found:")
print(classes)
print("Number of Classes:", len(classes))
# Out:
# Classes Found:
# ['side-road-left', 'right-hand-curve', 'gap-in-median', 'left-hand-curve']
# Number of Classes: 4

# %% [markdown]
# os.listdir(path) → Returns a list of names (strings) of the entries (files and directories) in the given path.

# %%
class_counts = {}

for cls in classes:
    class_path = os.path.join(train_path, cls)
    images = os.listdir(class_path)
    class_counts[cls] = len(images)

print("Image count per class:")
for cls, count in class_counts.items():
    print(f"{cls}: {count}")
# Out:
# Image count per class:
# side-road-left: 250
# right-hand-curve: 250
# gap-in-median: 250
# left-hand-curve: 250

# %% [markdown]
# os.path.join() safely joins folder paths
#
# images = os.listdir(class_path) → This returns a list of image file names inside that class folder.
#
# len(images) counts how many files are in the folder

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(class_counts.keys(), class_counts.values())
plt.title("Class Distribution")
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.show()

# %% [markdown]
# figsize=(10,5) means : Width = 10 inches, Height = 5 inches
#
# class_counts.keys() → Class names (x-axis)
#
# class_counts.values() → Number of images (y-axis)

# %%
import random

plt.figure(figsize=(10,10))

for i in range(4):
    random_class = random.choice(classes)
    class_path = os.path.join(train_path, random_class)
    random_image = random.choice(os.listdir(class_path))

    img_path = os.path.join(class_path, random_image)
    img = Image.open(img_path)

    plt.subplot(2,2,i+1)
    plt.imshow(img)
    plt.title(random_class)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# random.choice() selects one random element from a sequence (like a list or tuple).
#
# tight_layout() prevents overlapping.
#
# plt.subplot(rows, columns, position)
#
# img = Image.open(img_path) →
# Loads the image using Pillow.
